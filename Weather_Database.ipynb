# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import the requests library.
import requests

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 626

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
      
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
    
    try:
        #city_weather["weather"][0]["main"]=="Rain"
        city_rain = city_weather["rain"]["3h"]
        
    except:
        city_rain = 0
    
    try:
        #city_weather["weather"][0]["main"]=="Snow"
        city_snow = city_weather["snow"]["3h"]
        
    except:
        city_snow = 0
    
        
    city_data.append({"City": city.title(),
                    "Country": city_country,
                    "Date": city_date,
                    "Lat": city_lat,
                    "Lng": city_lng,
                    "Max Temp": city_max_temp,
                    "Humidity": city_humidity,
                    "Cloudiness": city_clouds,
                    "Wind Speed": city_wind,
                    "Current Description": city_desc,
                    "Rain inches (last 3 hrs)": city_rain,
                     "Snow inches (last 3 hrs)": city_snow})
    
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | surat thani
# Processing Record 2 of Set 1 | butaritari
# Processing Record 3 of Set 1 | lompoc
# Processing Record 4 of Set 1 | jumla
# Processing Record 5 of Set 1 | tiksi
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | kavieng
# Processing Record 8 of Set 1 | cape town
# Processing Record 9 of Set 1 | provideniya
# Processing Record 10 of Set 1 | marsaxlokk
# Processing Record 11 of Set 1 | mar del plata
# Processing Record 12 of Set 1 | bossangoa
# Processing Record 13 of Set 1 | alta floresta
# Processing Record 14 of Set 1 | port elizabeth
# Processing Record 15 of Set 1 | atuona
# Processing Record 16 of Set 1 | bluff
# Processing Record 17 of Set 1 | mataura
# Processing Record 18 of Set 1 | daru
# Processing Record 19 of Set 1 | new norfolk
# Processing Record 20 of Set 1 | richards bay
# Processing Record 21 of Set 1 | rikitea
# Processing Record 22 of Set 1 | sonthofen
# Processing Record 23 of Set 1 | puerto ayora
# Processing Record 24 of Set 1 | santiago del estero
# Processing Record 25 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 26 of Set 1 | jamestown
# Processing Record 27 of Set 1 | mattru
# Processing Record 28 of Set 1 | san cristobal
# Processing Record 29 of Set 1 | mackay
# Processing Record 30 of Set 1 | hilo
# Processing Record 31 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 32 of Set 1 | saskylakh
# Processing Record 33 of Set 1 | trairi
# Processing Record 34 of Set 1 | edwardsville
# Processing Record 35 of Set 1 | hunza
# City not found. Skipping...
# Processing Record 36 of Set 1 | geraldton
# Processing Record 37 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 1 | faanui
# Processing Record 39 of Set 1 | anloga
# Processing Record 40 of Set 1 | manokwari
# Processing Record 41 of Set 1 | vestmannaeyjar
# Processing Record 42 of Set 1 | come
# Processing Record 43 of Set 1 | lakselv
# Processing Record 44 of Set 1 | gizo
# Processing Record 45 of Set 1 | adrar
# Processing Record 46 of Set 1 | vanimo
# Processing Record 47 of Set 1 | beringovskiy
# Processing Record 48 of Set 1 | busselton
# Processing Record 49 of Set 1 | goderich
# Processing Record 50 of Set 1 | maragogi
# Processing Record 1 of Set 2 | ruidoso
# Processing Record 2 of Set 2 | yellowknife
# Processing Record 3 of Set 2 | balta
# Processing Record 4 of Set 2 | lukulu
# Processing Record 5 of Set 2 | sinnamary
# Processing Record 6 of Set 2 | ahuimanu
# Processing Record 7 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 8 of Set 2 | lagoa
# Processing Record 9 of Set 2 | ixtapa
# Processing Record 10 of Set 2 | airai
# Processing Record 11 of Set 2 | leshukonskoye
# Processing Record 12 of Set 2 | punta arenas
# Processing Record 13 of Set 2 | ribeira grande
# Processing Record 14 of Set 2 | hobart
# Processing Record 15 of Set 2 | necochea
# Processing Record 16 of Set 2 | khatanga
# Processing Record 17 of Set 2 | baijiantan
# Processing Record 18 of Set 2 | chodavaram
# Processing Record 19 of Set 2 | juneau
# Processing Record 20 of Set 2 | walvis bay
# Processing Record 21 of Set 2 | maroua
# Processing Record 22 of Set 2 | iqaluit
# Processing Record 23 of Set 2 | san quintin
# Processing Record 24 of Set 2 | mangrol
# Processing Record 25 of Set 2 | kamenka
# Processing Record 26 of Set 2 | oakham
# Processing Record 27 of Set 2 | fortuna
# Processing Record 28 of Set 2 | nishihara
# Processing Record 29 of Set 2 | riyadh
# Processing Record 30 of Set 2 | farafangana
# Processing Record 31 of Set 2 | longyearbyen
# Processing Record 32 of Set 2 | awbari
# Processing Record 33 of Set 2 | katsuura
# Processing Record 34 of Set 2 | vaini
# Processing Record 35 of Set 2 | kodiak
# Processing Record 36 of Set 2 | hasaki
# Processing Record 37 of Set 2 | panalingaan
# Processing Record 38 of Set 2 | bonthe
# Processing Record 39 of Set 2 | castro
# Processing Record 40 of Set 2 | eureka
# Processing Record 41 of Set 2 | marzuq
# Processing Record 42 of Set 2 | kapaa
# Processing Record 43 of Set 2 | yushu
# Processing Record 44 of Set 2 | tuktoyaktuk
# Processing Record 45 of Set 2 | port blair
# Processing Record 46 of Set 2 | raudeberg
# Processing Record 47 of Set 2 | libenge
# Processing Record 48 of Set 2 | hithadhoo
# Processing Record 49 of Set 2 | porkhov
# Processing Record 50 of Set 2 | saint-philippe
# Processing Record 1 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 3 | makhachkala
# Processing Record 3 of Set 3 | arraial do cabo
# Processing Record 4 of Set 3 | benghazi
# Processing Record 5 of Set 3 | wageningen
# Processing Record 6 of Set 3 | novyy urgal
# Processing Record 7 of Set 3 | bredasdorp
# Processing Record 8 of Set 3 | guayaramerin
# Processing Record 9 of Set 3 | burnie
# Processing Record 10 of Set 3 | port hawkesbury
# Processing Record 11 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 12 of Set 3 | ati
# Processing Record 13 of Set 3 | ulladulla
# Processing Record 14 of Set 3 | carnarvon
# Processing Record 15 of Set 3 | vao
# Processing Record 16 of Set 3 | kapoeta
# Processing Record 17 of Set 3 | sanary-sur-mer
# Processing Record 18 of Set 3 | marovoay
# Processing Record 19 of Set 3 | atar
# Processing Record 20 of Set 3 | thompson
# Processing Record 21 of Set 3 | belaya gora
# Processing Record 22 of Set 3 | torbay
# Processing Record 23 of Set 3 | el tigre
# Processing Record 24 of Set 3 | beyla
# Processing Record 25 of Set 3 | prince rupert
# Processing Record 26 of Set 3 | qaanaaq
# Processing Record 27 of Set 3 | campos do jordao
# Processing Record 28 of Set 3 | hihifo
# City not found. Skipping...
# Processing Record 29 of Set 3 | salina
# Processing Record 30 of Set 3 | nago
# Processing Record 31 of Set 3 | marawi
# Processing Record 32 of Set 3 | lima
# Processing Record 33 of Set 3 | tatawin
# Processing Record 34 of Set 3 | slave lake
# Processing Record 35 of Set 3 | antsohihy
# Processing Record 36 of Set 3 | cachoeira do sul
# Processing Record 37 of Set 3 | guanica
# Processing Record 38 of Set 3 | maceio
# Processing Record 39 of Set 3 | erenhot
# Processing Record 40 of Set 3 | nome
# Processing Record 41 of Set 3 | albany
# Processing Record 42 of Set 3 | dikson
# Processing Record 43 of Set 3 | upernavik
# Processing Record 44 of Set 3 | sayanogorsk
# Processing Record 45 of Set 3 | iberia
# Processing Record 46 of Set 3 | yerbogachen
# Processing Record 47 of Set 3 | el alto
# Processing Record 48 of Set 3 | chokurdakh
# Processing Record 49 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 50 of Set 3 | kenai
# Processing Record 1 of Set 4 | opuwo
# Processing Record 2 of Set 4 | beloha
# Processing Record 3 of Set 4 | bereda
# Processing Record 4 of Set 4 | narsaq
# Processing Record 5 of Set 4 | milak
# Processing Record 6 of Set 4 | napuro
# Processing Record 7 of Set 4 | east london
# Processing Record 8 of Set 4 | satitoa
# City not found. Skipping...
# Processing Record 9 of Set 4 | lavrentiya
# Processing Record 10 of Set 4 | kamphaeng phet
# Processing Record 11 of Set 4 | bangui
# Processing Record 12 of Set 4 | chengmai
# City not found. Skipping...
# Processing Record 13 of Set 4 | suez
# Processing Record 14 of Set 4 | ketchikan
# Processing Record 15 of Set 4 | avarua
# Processing Record 16 of Set 4 | vanavara
# Processing Record 17 of Set 4 | nikolskoye
# Processing Record 18 of Set 4 | rio verde de mato grosso
# Processing Record 19 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 20 of Set 4 | saldanha
# Processing Record 21 of Set 4 | pacific grove
# Processing Record 22 of Set 4 | krasnyy luch
# Processing Record 23 of Set 4 | uberaba
# Processing Record 24 of Set 4 | bethel
# Processing Record 25 of Set 4 | taoudenni
# Processing Record 26 of Set 4 | lichinga
# Processing Record 27 of Set 4 | burirao
# Processing Record 28 of Set 4 | bow island
# Processing Record 29 of Set 4 | teguldet
# Processing Record 30 of Set 4 | jinka
# Processing Record 31 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 32 of Set 4 | rosarito
# Processing Record 33 of Set 4 | kyren
# Processing Record 34 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 35 of Set 4 | souillac
# Processing Record 36 of Set 4 | goundam
# Processing Record 37 of Set 4 | eydhafushi
# Processing Record 38 of Set 4 | byron bay
# Processing Record 39 of Set 4 | cockburn town
# Processing Record 40 of Set 4 | panzhihua
# Processing Record 41 of Set 4 | kismayo
# Processing Record 42 of Set 4 | kattivakkam
# Processing Record 43 of Set 4 | nara
# Processing Record 44 of Set 4 | russell
# Processing Record 45 of Set 4 | port alfred
# Processing Record 46 of Set 4 | hambantota
# Processing Record 47 of Set 4 | talnakh
# Processing Record 48 of Set 4 | rawannawi
# City not found. Skipping...
# Processing Record 49 of Set 4 | rocha
# Processing Record 50 of Set 4 | henties bay
# Processing Record 1 of Set 5 | husavik
# Processing Record 2 of Set 5 | grindavik
# Processing Record 3 of Set 5 | codrington
# Processing Record 4 of Set 5 | kwinana
# Processing Record 5 of Set 5 | usinsk
# Processing Record 6 of Set 5 | tomatlan
# Processing Record 7 of Set 5 | soe
# Processing Record 8 of Set 5 | kintampo
# Processing Record 9 of Set 5 | isangel
# Processing Record 10 of Set 5 | jinji
# Processing Record 11 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 12 of Set 5 | kidal
# Processing Record 13 of Set 5 | redding
# Processing Record 14 of Set 5 | tarudant
# City not found. Skipping...
# Processing Record 15 of Set 5 | we
# City not found. Skipping...
# Processing Record 16 of Set 5 | santiago
# Processing Record 17 of Set 5 | pangai
# Processing Record 18 of Set 5 | shache
# Processing Record 19 of Set 5 | kruisfontein
# Processing Record 20 of Set 5 | teocaltiche
# Processing Record 21 of Set 5 | dong hoi
# Processing Record 22 of Set 5 | saint-pierre
# Processing Record 23 of Set 5 | nioro
# Processing Record 24 of Set 5 | marsh harbour
# Processing Record 25 of Set 5 | bilma
# Processing Record 26 of Set 5 | northam
# Processing Record 27 of Set 5 | severodvinsk
# Processing Record 28 of Set 5 | poltavka
# Processing Record 29 of Set 5 | la rioja
# Processing Record 30 of Set 5 | tajimi
# Processing Record 31 of Set 5 | malwan
# City not found. Skipping...
# Processing Record 32 of Set 5 | baykit
# Processing Record 33 of Set 5 | mount isa
# Processing Record 34 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 35 of Set 5 | svay rieng
# Processing Record 36 of Set 5 | bengkulu
# Processing Record 37 of Set 5 | mahebourg
# Processing Record 38 of Set 5 | cessnock
# Processing Record 39 of Set 5 | mandalgovi
# Processing Record 40 of Set 5 | georgetown
# Processing Record 41 of Set 5 | muros
# Processing Record 42 of Set 5 | alto araguaia
# Processing Record 43 of Set 5 | lebu
# Processing Record 44 of Set 5 | severo-kurilsk
# Processing Record 45 of Set 5 | half moon bay
# Processing Record 46 of Set 5 | lorengau
# Processing Record 47 of Set 5 | burns lake
# Processing Record 48 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 49 of Set 5 | hermanus
# Processing Record 50 of Set 5 | zernograd
# Processing Record 1 of Set 6 | makakilo city
# Processing Record 2 of Set 6 | portland
# Processing Record 3 of Set 6 | dharmapuri
# Processing Record 4 of Set 6 | krasnorechenskiy
# Processing Record 5 of Set 6 | susehri
# Processing Record 6 of Set 6 | shenjiamen
# Processing Record 7 of Set 6 | seoul
# Processing Record 8 of Set 6 | nantucket
# Processing Record 9 of Set 6 | jiwani
# Processing Record 10 of Set 6 | karambakkudi
# Processing Record 11 of Set 6 | college
# Processing Record 12 of Set 6 | cidreira
# Processing Record 13 of Set 6 | ambodifototra
# City not found. Skipping...
# Processing Record 14 of Set 6 | santa teresa
# Processing Record 15 of Set 6 | luderitz
# Processing Record 16 of Set 6 | saint george
# Processing Record 17 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 18 of Set 6 | fenelon falls
# Processing Record 19 of Set 6 | olafsvik
# Processing Record 20 of Set 6 | chinhoyi
# Processing Record 21 of Set 6 | tabou
# Processing Record 22 of Set 6 | yar-sale
# Processing Record 23 of Set 6 | maksi
# Processing Record 24 of Set 6 | mayahi
# Processing Record 25 of Set 6 | katherine
# Processing Record 26 of Set 6 | avera
# Processing Record 27 of Set 6 | tanete
# Processing Record 28 of Set 6 | vaitape
# Processing Record 29 of Set 6 | mitsamiouli
# Processing Record 30 of Set 6 | roma
# Processing Record 31 of Set 6 | pevek
# Processing Record 32 of Set 6 | rio gallegos
# Processing Record 33 of Set 6 | maryville
# Processing Record 34 of Set 6 | norman wells
# Processing Record 35 of Set 6 | boo
# Processing Record 36 of Set 6 | tvoroyri
# Processing Record 37 of Set 6 | naestved
# Processing Record 38 of Set 6 | tasiilaq
# Processing Record 39 of Set 6 | mizan teferi
# Processing Record 40 of Set 6 | laguna
# Processing Record 41 of Set 6 | keflavik
# Processing Record 42 of Set 6 | kollo
# Processing Record 43 of Set 6 | artyk
# City not found. Skipping...
# Processing Record 44 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 45 of Set 6 | kargopol
# Processing Record 46 of Set 6 | bodden town
# Processing Record 47 of Set 6 | klaksvik
# Processing Record 48 of Set 6 | tashtyp
# Processing Record 49 of Set 6 | broken hill
# Processing Record 50 of Set 6 | deputatskiy
# Processing Record 1 of Set 7 | huntsville
# Processing Record 2 of Set 7 | lakes entrance
# Processing Record 3 of Set 7 | hobyo
# Processing Record 4 of Set 7 | ponta do sol
# Processing Record 5 of Set 7 | kununurra
# Processing Record 6 of Set 7 | chimbote
# Processing Record 7 of Set 7 | nagato
# Processing Record 8 of Set 7 | sinaloa
# Processing Record 9 of Set 7 | wenatchee
# Processing Record 10 of Set 7 | lensk
# Processing Record 11 of Set 7 | cabo san lucas
# Processing Record 12 of Set 7 | yekaterinovka
# Processing Record 13 of Set 7 | port lincoln
# Processing Record 14 of Set 7 | mae sai
# Processing Record 15 of Set 7 | fergus falls
# Processing Record 16 of Set 7 | bestobe
# Processing Record 17 of Set 7 | astaneh-ye ashrafiyeh
# Processing Record 18 of Set 7 | shonguy
# Processing Record 19 of Set 7 | sitka
# Processing Record 20 of Set 7 | san vicente
# Processing Record 21 of Set 7 | port macquarie
# Processing Record 22 of Set 7 | visnes
# Processing Record 23 of Set 7 | yurty
# Processing Record 24 of Set 7 | harper
# Processing Record 25 of Set 7 | victoria
# Processing Record 26 of Set 7 | kavaratti
# Processing Record 27 of Set 7 | healesville
# Processing Record 28 of Set 7 | tumbi
# Processing Record 29 of Set 7 | lyngseidet
# Processing Record 30 of Set 7 | laiyang
# Processing Record 31 of Set 7 | korla
# Processing Record 32 of Set 7 | anadyr
# Processing Record 33 of Set 7 | shar
# Processing Record 34 of Set 7 | champerico
# Processing Record 35 of Set 7 | xam nua
# Processing Record 36 of Set 7 | fene
# Processing Record 37 of Set 7 | atambua
# Processing Record 38 of Set 7 | dunedin
# Processing Record 39 of Set 7 | cumaribo
# City not found. Skipping...
# Processing Record 40 of Set 7 | ibra
# Processing Record 41 of Set 7 | gazimurskiy zavod
# Processing Record 42 of Set 7 | maldonado
# Processing Record 43 of Set 7 | sao joao da barra
# Processing Record 44 of Set 7 | chuy
# Processing Record 45 of Set 7 | ondorhaan
# City not found. Skipping...
# Processing Record 46 of Set 7 | talcahuano
# Processing Record 47 of Set 7 | mahanje
# Processing Record 48 of Set 7 | bangassou
# Processing Record 49 of Set 7 | virginia beach
# Processing Record 50 of Set 7 | samarai
# Processing Record 1 of Set 8 | luba
# Processing Record 2 of Set 8 | zilair
# Processing Record 3 of Set 8 | zyryanka
# Processing Record 4 of Set 8 | port hardy
# Processing Record 5 of Set 8 | am timan
# Processing Record 6 of Set 8 | ilulissat
# Processing Record 7 of Set 8 | umm lajj
# Processing Record 8 of Set 8 | bambous virieux
# Processing Record 9 of Set 8 | khormuj
# City not found. Skipping...
# Processing Record 10 of Set 8 | ye
# City not found. Skipping...
# Processing Record 11 of Set 8 | cogoleto
# Processing Record 12 of Set 8 | houma
# Processing Record 13 of Set 8 | chaozhou
# Processing Record 14 of Set 8 | pontes e lacerda
# Processing Record 15 of Set 8 | chapais
# Processing Record 16 of Set 8 | ardistan
# City not found. Skipping...
# Processing Record 17 of Set 8 | banfora
# Processing Record 18 of Set 8 | burgeo
# Processing Record 19 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 20 of Set 8 | flinders
# Processing Record 21 of Set 8 | tura
# Processing Record 22 of Set 8 | dingle
# Processing Record 23 of Set 8 | meulaboh
# Processing Record 24 of Set 8 | sao raimundo das mangabeiras
# Processing Record 25 of Set 8 | lyubinskiy
# Processing Record 26 of Set 8 | sarankhola
# Processing Record 27 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 28 of Set 8 | burica
# City not found. Skipping...
# Processing Record 29 of Set 8 | durazno
# Processing Record 30 of Set 8 | kamaishi
# Processing Record 31 of Set 8 | sokode
# Processing Record 32 of Set 8 | hohhot
# Processing Record 33 of Set 8 | kudahuvadhoo
# Processing Record 34 of Set 8 | panguna
# Processing Record 35 of Set 8 | buenos aires
# Processing Record 36 of Set 8 | tautira
# Processing Record 37 of Set 8 | altay
# Processing Record 38 of Set 8 | dosso
# Processing Record 39 of Set 8 | batagay-alyta
# Processing Record 40 of Set 8 | esperance
# Processing Record 41 of Set 8 | eyl
# Processing Record 42 of Set 8 | maesteg
# Processing Record 43 of Set 8 | shangrao
# Processing Record 44 of Set 8 | general roca
# Processing Record 45 of Set 8 | preobrazheniye
# Processing Record 46 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 47 of Set 8 | pankrushikha
# Processing Record 48 of Set 8 | lata
# Processing Record 49 of Set 8 | bairiki
# Processing Record 50 of Set 8 | pisco
# Processing Record 1 of Set 9 | san joaquin
# Processing Record 2 of Set 9 | broome
# Processing Record 3 of Set 9 | palu
# Processing Record 4 of Set 9 | taber
# Processing Record 5 of Set 9 | yenagoa
# Processing Record 6 of Set 9 | poum
# Processing Record 7 of Set 9 | kinsale
# Processing Record 8 of Set 9 | nautla
# Processing Record 9 of Set 9 | alcantarilla
# Processing Record 10 of Set 9 | borogontsy
# Processing Record 11 of Set 9 | srednekolymsk
# Processing Record 12 of Set 9 | baker city
# Processing Record 13 of Set 9 | rambha
# Processing Record 14 of Set 9 | svetlogorsk
# Processing Record 15 of Set 9 | la palma
# Processing Record 16 of Set 9 | jahrom
# City not found. Skipping...
# Processing Record 17 of Set 9 | launceston
# Processing Record 18 of Set 9 | tungkang
# City not found. Skipping...
# Processing Record 19 of Set 9 | canelones
# Processing Record 20 of Set 9 | chanal
# Processing Record 21 of Set 9 | oussouye
# Processing Record 22 of Set 9 | berlevag
# Processing Record 23 of Set 9 | sur
# Processing Record 24 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 25 of Set 9 | tsuruoka
# Processing Record 26 of Set 9 | conde
# Processing Record 27 of Set 9 | chalchihuites
# Processing Record 28 of Set 9 | sataua
# City not found. Skipping...
# Processing Record 29 of Set 9 | touros
# Processing Record 30 of Set 9 | kapuskasing
# Processing Record 31 of Set 9 | aklavik
# Processing Record 32 of Set 9 | cherskiy
# Processing Record 33 of Set 9 | ewa beach
# Processing Record 34 of Set 9 | ostrovnoy
# Processing Record 35 of Set 9 | abu dhabi
# Processing Record 36 of Set 9 | shepetivka
# Processing Record 37 of Set 9 | carnduff
# Processing Record 38 of Set 9 | lancaster
# Processing Record 39 of Set 9 | nueva loja
# Processing Record 40 of Set 9 | buchanan
# Processing Record 41 of Set 9 | strezhevoy
# Processing Record 42 of Set 9 | pingliang
# Processing Record 43 of Set 9 | clyde river
# Processing Record 44 of Set 9 | yurga
# Processing Record 45 of Set 9 | puquio
# Processing Record 46 of Set 9 | paamiut
# Processing Record 47 of Set 9 | celestun
# Processing Record 48 of Set 9 | barrow
# Processing Record 49 of Set 9 | aguimes
# Processing Record 50 of Set 9 | chicama
# Processing Record 1 of Set 10 | pahrump
# Processing Record 2 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 10 | raymondville
# Processing Record 4 of Set 10 | yinchuan
# Processing Record 5 of Set 10 | balotra
# Processing Record 6 of Set 10 | malakal
# Processing Record 7 of Set 10 | vysokogornyy
# Processing Record 8 of Set 10 | san patricio
# Processing Record 9 of Set 10 | mason city
# Processing Record 10 of Set 10 | banda aceh
# Processing Record 11 of Set 10 | nemuro
# Processing Record 12 of Set 10 | mabaruma
# Processing Record 13 of Set 10 | kupang
# Processing Record 14 of Set 10 | kerman
# Processing Record 15 of Set 10 | kangasala
# Processing Record 16 of Set 10 | margate
# Processing Record 17 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 18 of Set 10 | norton
# Processing Record 19 of Set 10 | sorland
# Processing Record 20 of Set 10 | callaguip
# Processing Record 21 of Set 10 | abu samrah
# Processing Record 22 of Set 10 | zabkowice slaskie
# Processing Record 23 of Set 10 | oskarshamn
# Processing Record 24 of Set 10 | naze
# Processing Record 25 of Set 10 | alappuzha
# Processing Record 26 of Set 10 | coquimbo
# Processing Record 27 of Set 10 | manzil tamim
# City not found. Skipping...
# Processing Record 28 of Set 10 | barbar
# City not found. Skipping...
# Processing Record 29 of Set 10 | tucurui
# Processing Record 30 of Set 10 | whitehorse
# Processing Record 31 of Set 10 | grand gaube
# Processing Record 32 of Set 10 | anuchino
# Processing Record 33 of Set 10 | abancay
# Processing Record 34 of Set 10 | la ronge
# Processing Record 35 of Set 10 | vila franca do campo
# Processing Record 36 of Set 10 | vereya
# Processing Record 37 of Set 10 | baglung
# Processing Record 38 of Set 10 | khartoum
# Processing Record 39 of Set 10 | sindor
# Processing Record 40 of Set 10 | rawson
# Processing Record 41 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 42 of Set 10 | humaita
# Processing Record 43 of Set 10 | saint-georges
# Processing Record 44 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 45 of Set 10 | ilhabela
# Processing Record 46 of Set 10 | flin flon
# Processing Record 47 of Set 10 | nanortalik
# Processing Record 48 of Set 10 | sioux lookout
# Processing Record 49 of Set 10 | caborca
# Processing Record 50 of Set 10 | puerto del rosario
# Processing Record 1 of Set 11 | amapa
# Processing Record 2 of Set 11 | kem
# Processing Record 3 of Set 11 | kaitangata
# Processing Record 4 of Set 11 | fort saint john
# City not found. Skipping...
# Processing Record 5 of Set 11 | telgte
# Processing Record 6 of Set 11 | novo aripuana
# Processing Record 7 of Set 11 | birjand
# Processing Record 8 of Set 11 | dehloran
# Processing Record 9 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 10 of Set 11 | sao filipe
# Processing Record 11 of Set 11 | ust-kuyga
# Processing Record 12 of Set 11 | salina cruz
# Processing Record 13 of Set 11 | shizukuishi
# Processing Record 14 of Set 11 | karwar
# Processing Record 15 of Set 11 | verkhnyaya inta
# Processing Record 16 of Set 11 | gdov
# Processing Record 17 of Set 11 | dharchula
# Processing Record 18 of Set 11 | pucallpa
# Processing Record 19 of Set 11 | puerto baquerizo moreno
# Processing Record 20 of Set 11 | slonim
# Processing Record 21 of Set 11 | amuntai
# Processing Record 22 of Set 11 | torata
# Processing Record 23 of Set 11 | mahbubnagar
# Processing Record 24 of Set 11 | chaklasi
# Processing Record 25 of Set 11 | hakkari
# Processing Record 26 of Set 11 | bubaque
# Processing Record 27 of Set 11 | bobrovytsya
# Processing Record 28 of Set 11 | bongandanga
# Processing Record 29 of Set 11 | miguel hidalgo
# Processing Record 30 of Set 11 | galgani
# City not found. Skipping...
# Processing Record 31 of Set 11 | forestville
# Processing Record 32 of Set 11 | tezu
# Processing Record 33 of Set 11 | mogwase
# Processing Record 34 of Set 11 | timra
# Processing Record 35 of Set 11 | tutoia
# Processing Record 36 of Set 11 | bolshaya sosnova
# Processing Record 37 of Set 11 | merauke
# Processing Record 38 of Set 11 | cabedelo
# Processing Record 39 of Set 11 | quatre cocos
# Processing Record 40 of Set 11 | nioki
# Processing Record 41 of Set 11 | novyy nekouz
# Processing Record 42 of Set 11 | the valley
# Processing Record 43 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 44 of Set 11 | sadiqabad
# Processing Record 45 of Set 11 | vichuga
# Processing Record 46 of Set 11 | leningradskiy
# Processing Record 47 of Set 11 | labuhan
# Processing Record 48 of Set 11 | vilyuysk
# Processing Record 49 of Set 11 | vire
# Processing Record 50 of Set 11 | temaraia
# City not found. Skipping...
# Processing Record 1 of Set 12 | komsomolskiy
# Processing Record 2 of Set 12 | upata
# Processing Record 3 of Set 12 | mezhova
# Processing Record 4 of Set 12 | morgan city
# Processing Record 5 of Set 12 | cayenne
# Processing Record 6 of Set 12 | termoli
# Processing Record 7 of Set 12 | khilok
# Processing Record 8 of Set 12 | salinopolis
# Processing Record 9 of Set 12 | tra vinh
# Processing Record 10 of Set 12 | utiroa
# City not found. Skipping...
# Processing Record 11 of Set 12 | qitaihe
# Processing Record 12 of Set 12 | apostolove
# Processing Record 13 of Set 12 | hearst
# Processing Record 14 of Set 12 | springdale
# Processing Record 15 of Set 12 | villarrica
# Processing Record 16 of Set 12 | ust-nera
# Processing Record 17 of Set 12 | port-gentil
# Processing Record 18 of Set 12 | umm kaddadah
# Processing Record 19 of Set 12 | puerto madryn
# Processing Record 20 of Set 12 | weifang
# Processing Record 21 of Set 12 | gat
# Processing Record 22 of Set 12 | mount gambier
# Processing Record 23 of Set 12 | vokhtoga
# Processing Record 24 of Set 12 | ipixuna
# Processing Record 25 of Set 12 | castanhal
# Processing Record 26 of Set 12 | angoram
# Processing Record 27 of Set 12 | shunyi
# Processing Record 28 of Set 12 | junin
# Processing Record 29 of Set 12 | inhambane
# Processing Record 30 of Set 12 | penzance
# Processing Record 31 of Set 12 | lufilufi
# Processing Record 32 of Set 12 | faya
# Processing Record 33 of Set 12 | okhotsk
# Processing Record 34 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 35 of Set 12 | tuatapere
# Processing Record 36 of Set 12 | andenes
# Processing Record 37 of Set 12 | natalio
# Processing Record 38 of Set 12 | hare bay
# Processing Record 39 of Set 12 | belawan
# Processing Record 40 of Set 12 | hamilton
# Processing Record 41 of Set 12 | jalu
# Processing Record 42 of Set 12 | saint-joseph
# Processing Record 43 of Set 12 | kishi
# Processing Record 44 of Set 12 | mayumba
# Processing Record 45 of Set 12 | sivaki
# Processing Record 46 of Set 12 | yarkovo
# Processing Record 47 of Set 12 | sechura
# Processing Record 48 of Set 12 | san policarpo
# Processing Record 49 of Set 12 | pedernales
# Processing Record 50 of Set 12 | monrovia
# Processing Record 1 of Set 13 | mlonggo
# Processing Record 2 of Set 13 | manaure
# Processing Record 3 of Set 13 | leninskoye
# Processing Record 4 of Set 13 | solano
# Processing Record 5 of Set 13 | tagusao
# Processing Record 6 of Set 13 | mocuba
# Processing Record 7 of Set 13 | shelburne
# Processing Record 8 of Set 13 | vallenar
# Processing Record 9 of Set 13 | kade
# Processing Record 10 of Set 13 | port moresby
# Processing Record 11 of Set 13 | tammisaari
# Processing Record 12 of Set 13 | nakonde
# Processing Record 13 of Set 13 | kampong thum
# Processing Record 14 of Set 13 | moshenskoye
# Processing Record 15 of Set 13 | vitimskiy
# City not found. Skipping...
# Processing Record 16 of Set 13 | caravelas
# Processing Record 17 of Set 13 | kristiinankaupunki
# Processing Record 18 of Set 13 | vigia del fuerte
# Processing Record 19 of Set 13 | tortoli
# Processing Record 20 of Set 13 | khash
# Processing Record 21 of Set 13 | hofn
# Processing Record 22 of Set 13 | cavalcante
# Processing Record 23 of Set 13 | shingu
# Processing Record 24 of Set 13 | mahibadhoo
# Processing Record 25 of Set 13 | perth
# Processing Record 26 of Set 13 | whyalla
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 626

# %%
city_data
# Out:
# [{'City': 'Surat Thani',
#   'Country': 'TH',
#   'Date': '2020-02-24 05:05:33',
#   'Lat': 9.14,
#   'Lng': 99.33,
#   'Max Temp': 106,
#   'Humidity': 58,
#   'Cloudiness': 20,
#   'Wind Speed': 10.29,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Butaritari',
#   'Country': 'KI',
#   'Date': '2020-02-24 05:05:33',
#   'Lat': 3.07,
#   'Lng': 172.79,
#   'Max Temp': 82.06,
#   'Humidity': 84,
#   'Cloudiness': 68,
#   'Wind Speed': 26.22,
#   'Current Description': 'moderate rain',
#   'Rain inches (last 3 hrs)': 9.44,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Lompoc',
#   'Country': 'US',
#   'Date': '2020-02-24 05:05:33',
#   'Lat': 34.64,
#   'Lng': -120.46,
#   'Max Temp': 55.4,
#   'Humidity': 87,
#   'Cloudiness': 90,
#   'Wind Speed': 3.36,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Jumla',
#   'Country': 'NP',
#   'Date': '2020-02-24 05:05:33',
#   'Lat': 29.27,
#   'Lng': 82.18,
#   'Max Temp': 49.05,
#   'Humidity': 29,
#   'Cloudiness': 24,
#   'Wind Speed': 4.32,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Tiksi',
#   'Country': 'RU',
#   'Date': '2020-02-24 05:05:34',
#   'Lat': 71.69,
#   'Lng': 128.87,
#   'Max Temp': -3.64,
#   'Humidity': 87,
#   'Cloudiness': 98,
#   'Wind Speed': 7.31,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Ushuaia',
#   'Country': 'AR',
#   'Date': '2020-02-24 05:03:05',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 42.8,
#   'Humidity': 70,
#   'Cloudiness': 75,
#   'Wind Speed': 25.28,
#   'Current Description': 'light intensity drizzle',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Kavieng',
#   'Country': 'PG',
#   'Date': '2020-02-24 05:05:34',
#   'Lat': -2.57,
#   'Lng': 150.8,
#   'Max Temp': 84.65,
#   'Humidity': 73,
#   'Cloudiness': 12,
#   'Wind Speed': 12.64,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Cape Town',
#   'Country': 'ZA',
#   'Date': '2020-02-24 05:04:37',
#   'Lat': -33.93,
#   'Lng': 18.42,
#   'Max Temp': 64,
#   'Humidity': 63,
#   'Cloudiness': 0,
#   'Wind Speed': 14.99,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Provideniya',
#   'Country': 'RU',
#   'Date': '2020-02-24 05:05:34',
#   'Lat': 64.38,
#   'Lng': -173.3,
#   'Max Temp': -3.96,
#   'Humidity': 63,
#   'Cloudiness': 32,
#   'Wind Speed': 2.57,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Marsaxlokk',
#   'Country': 'MT',
#   'Date': '2020-02-24 05:05:35',
#   'Lat': 35.84,
#   'Lng': 14.54,
#   'Max Temp': 55.99,
#   'Humidity': 87,
#   'Cloudiness': 20,
#   'Wind Speed': 12.75,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Mar Del Plata',
#   'Country': 'AR',
#   'Date': '2020-02-24 05:02:20',
#   'Lat': -38,
#   'Lng': -57.56,
#   'Max Temp': 64.99,
#   'Humidity': 88,
#   'Cloudiness': 0,
#   'Wind Speed': 10.29,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Bossangoa',
#   'Country': 'CF',
#   'Date': '2020-02-24 05:05:35',
#   'Lat': 6.49,
#   'Lng': 17.46,
#   'Max Temp': 70.02,
#   'Humidity': 20,
#   'Cloudiness': 71,
#   'Wind Speed': 5.88,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Alta Floresta',
#   'Country': 'BR',
#   'Date': '2020-02-24 05:05:35',
#   'Lat': -9.88,
#   'Lng': -56.09,
#   'Max Temp': 71.91,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 1.39,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Port Elizabeth',
#   'Country': 'ZA',
#   'Date': '2020-02-24 05:05:35',
#   'Lat': -33.92,
#   'Lng': 25.57,
#   'Max Temp': 51.8,
#   'Humidity': 93,
#   'Cloudiness': 11,
#   'Wind Speed': 2.24,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Atuona',
#   'Country': 'PF',
#   'Date': '2020-02-24 05:05:36',
#   'Lat': -9.8,
#   'Lng': -139.03,
#   'Max Temp': 81.23,
#   'Humidity': 79,
#   'Cloudiness': 18,
#   'Wind Speed': 14.52,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Bluff',
#   'Country': 'NZ',
#   'Date': '2020-02-24 05:04:39',
#   'Lat': -46.6,
#   'Lng': 168.33,
#   'Max Temp': 64.99,
#   'Humidity': 63,
#   'Cloudiness': 25,
#   'Wind Speed': 14,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Mataura',
#   'Country': 'NZ',
#   'Date': '2020-02-24 05:05:36',
#   'Lat': -46.19,
#   'Lng': 168.86,
#   'Max Temp': 64.99,
#   'Humidity': 63,
#   'Cloudiness': 6,
#   'Wind Speed': 14,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Daru',
#   'Country': 'PG',
#   'Date': '2020-02-24 05:05:36',
#   'Lat': -9.08,
#   'Lng': 143.21,
#   'Max Temp': 93.72,
#   'Humidity': 51,
#   'Cloudiness': 96,
#   'Wind Speed': 5.46,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'New Norfolk',
#   'Country': 'AU',
#   'Date': '2020-02-24 05:04:43',
#   'Lat': -42.78,
#   'Lng': 147.06,
#   'Max Temp': 72,
#   'Humidity': 56,
#   'Cloudiness': 75,
#   'Wind Speed': 12.75,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Richards Bay',
#   'Country': 'ZA',
#   'Date': '2020-02-24 05:05:37',
#   'Lat': -28.78,
#   'Lng': 32.04,
#   'Max Temp': 73.18,
#   'Humidity': 66,
#   'Cloudiness': 98,
#   'Wind Speed': 11.95,
#   'Current Description': 'light rain',
#   'Rain inches (last 3 hrs)': 0.88,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Rikitea',
#   'Country': 'PF',
#   'Date': '2020-02-24 05:05:37',
#   'Lat': -23.12,
#   'Lng': -134.97,
#   'Max Temp': 79.81,
#   'Humidity': 71,
#   'Cloudiness': 7,
#   'Wind Speed': 6.71,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Sonthofen',
#   'Country': 'DE',
#   'Date': '2020-02-24 05:05:37',
#   'Lat': 47.52,
#   'Lng': 10.28,
#   'Max Temp': 55,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 8.05,
#   'Current Description': 'moderate rain',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Puerto Ayora',
#   'Country': 'EC',
#   'Date': '2020-02-24 05:04:30',
#   'Lat': -0.74,
#   'Lng': -90.35,
#   'Max Temp': 78.01,
#   'Humidity': 100,
#   'Cloudiness': 88,
#   'Wind Speed': 4.68,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Santiago Del Estero',
#   'Country': 'AR',
#   'Date': '2020-02-24 05:05:38',
#   'Lat': -27.8,
#   'Lng': -64.26,
#   'Max Temp': 63.25,
#   'Humidity': 54,
#   'Cloudiness': 0,
#   'Wind Speed': 7.87,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Grand River South East',
#   'Country': 'AR',
#   'Date': '2020-02-24 05:05:38',
#   'Lat': -27.8,
#   'Lng': -64.26,
#   'Max Temp': 63.25,
#   'Humidity': 54,
#   'Cloudiness': 0,
#   'Wind Speed': 7.87,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Jamestown',
#   'Country': 'US',
#   'Date': '2020-02-24 05:04:14',
#   'Lat': 42.1,
#   'Lng': -79.24,
#   'Max Temp': 44.6,
#   'Humidity': 41,
#   'Cloudiness': 1,
#   'Wind Speed': 11.41,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Mattru',
#   'Country': 'SL',
#   'Date': '2020-02-24 05:05:38',
#   'Lat': 7.62,
#   'Lng': -11.83,
#   'Max Temp': 76.3,
#   'Humidity': 85,
#   'Cloudiness': 92,
#   'Wind Speed': 0.27,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'San Cristobal',
#   'Country': 'VE',
#   'Date': '2020-02-24 05:05:39',
#   'Lat': 7.77,
#   'Lng': -72.22,
#   'Max Temp': 78.8,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 0.47,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Mackay',
#   'Country': 'AU',
#   'Date': '2020-02-24 05:05:39',
#   'Lat': -21.15,
#   'Lng': 149.2,
#   'Max Temp': 82.99,
#   'Humidity': 78,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Hilo',
#   'Country': 'US',
#   'Date': '2020-02-24 05:01:54',
#   'Lat': 19.73,
#   'Lng': -155.09,
#   'Max Temp': 75.2,
#   'Humidity': 69,
#   'Cloudiness': 20,
#   'Wind Speed': 6.93,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Belushya Guba',
#   'Country': 'US',
#   'Date': '2020-02-24 05:01:54',
#   'Lat': 19.73,
#   'Lng': -155.09,
#   'Max Temp': 75.2,
#   'Humidity': 69,
#   'Cloudiness': 20,
#   'Wind Speed': 6.93,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Saskylakh',
#   'Country': 'RU',
#   'Date': '2020-02-24 05:05:39',
#   'Lat': 71.92,
#   'Lng': 114.08,
#   'Max Temp': 12.9,
#   'Humidity': 92,
#   'Cloudiness': 88,
#   'Wind Speed': 11.07,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Trairi',
#   'Country': 'BR',
#   'Date': '2020-02-24 05:04:53',
#   'Lat': -3.28,
#   'Lng': -39.27,
#   'Max Temp': 73.27,
#   'Humidity': 97,
#   'Cloudiness': 31,
#   'Wind Speed': 2.51,
#   'Current Description': 'light rain',
#   'Rain inches (last 3 hrs)': 0.19,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Edwardsville',
#   'Country': 'US',
#   'Date': '2020-02-24 05:05:40',
#   'Lat': 38.81,
#   'Lng': -89.95,
#   'Max Temp': 48.99,
#   'Humidity': 81,
#   'Cloudiness': 90,
#   'Wind Speed': 6.93,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Hunza',
#   'Country': 'US',
#   'Date': '2020-02-24 05:05:40',
#   'Lat': 38.81,
#   'Lng': -89.95,
#   'Max Temp': 48.99,
#   'Humidity': 81,
#   'Cloudiness': 90,
#   'Wind Speed': 6.93,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Geraldton',
#   'Country': 'AU',
#   'Date': '2020-02-24 05:05:40',
#   'Lat': -28.77,
#   'Lng': 114.6,
#   'Max Temp': 82.4,
#   'Humidity': 65,
#   'Cloudiness': 0,
#   'Wind Speed': 14.99,
#   'Current Description': 'light rain',
#   'Rain inches (last 3 hrs)': 0.63,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Taolanaro',
#   'Country': 'AU',
#   'Date': '2020-02-24 05:05:40',
#   'Lat': -28.77,
#   'Lng': 114.6,
#   'Max Temp': 82.4,
#   'Humidity': 65,
#   'Cloudiness': 0,
#   'Wind Speed': 14.99,
#   'Current Description': 'light rain',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Faanui',
#   'Country': 'PF',
#   'Date': '2020-02-24 05:05:23',
#   'Lat': -16.48,
#   'Lng': -151.75,
#   'Max Temp': 83.3,
#   'Humidity': 73,
#   'Cloudiness': 19,
#   'Wind Speed': 11.68,
#   'Current Description': 'light rain',
#   'Rain inches (last 3 hrs)': 0.13,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Anloga',
#   'Country': 'GH',
#   'Date': '2020-02-24 05:05:41',
#   'Lat': 5.79,
#   'Lng': 0.9,
#   'Max Temp': 84.2,
#   'Humidity': 83,
#   'Cloudiness': 40,
#   'Wind Speed': 6.93,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Manokwari',
#   'Country': 'ID',
#   'Date': '2020-02-24 05:05:41',
#   'Lat': -0.87,
#   'Lng': 134.08,
#   'Max Temp': 76.26,
#   'Humidity': 84,
#   'Cloudiness': 98,
#   'Wind Speed': 1.63,
#   'Current Description': 'light rain',
#   'Rain inches (last 3 hrs)': 1.06,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Vestmannaeyjar',
#   'Country': 'IS',
#   'Date': '2020-02-24 05:03:04',
#   'Lat': 63.44,
#   'Lng': -20.27,
#   'Max Temp': 40.24,
#   'Humidity': 64,
#   'Cloudiness': 100,
#   'Wind Speed': 21.09,
#   'Current Description': 'light snow',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 1.19},
#  {'City': 'Come',
#   'Country': 'BJ',
#   'Date': '2020-02-24 05:05:42',
#   'Lat': 6.41,
#   'Lng': 1.88,
#   'Max Temp': 84.2,
#   'Humidity': 83,
#   'Cloudiness': 40,
#   'Wind Speed': 9.17,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Lakselv',
#   'Country': 'NO',
#   'Date': '2020-02-24 05:05:42',
#   'Lat': 70.05,
#   'Lng': 24.97,
#   'Max Temp': 33.8,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 32.21,
#   'Current Description': 'snow',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 3.87},
#  {'City': 'Gizo',
#   'Country': 'SB',
#   'Date': '2020-02-24 05:05:42',
#   'Lat': -8.1,
#   'Lng': 156.84,
#   'Max Temp': 81.34,
#   'Humidity': 80,
#   'Cloudiness': 47,
#   'Wind Speed': 4.41,
#   'Current Description': 'light rain',
#   'Rain inches (last 3 hrs)': 0.38,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Adrar',
#   'Country': 'MR',
#   'Date': '2020-02-24 05:05:42',
#   'Lat': 20.5,
#   'Lng': -10.07,
#   'Max Temp': 74.61,
#   'Humidity': 12,
#   'Cloudiness': 100,
#   'Wind Speed': 15.75,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Vanimo',
#   'Country': 'PG',
#   'Date': '2020-02-24 05:01:06',
#   'Lat': -2.67,
#   'Lng': 141.3,
#   'Max Temp': 83.3,
#   'Humidity': 79,
#   'Cloudiness': 67,
#   'Wind Speed': 12.97,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Beringovskiy',
#   'Country': 'RU',
#   'Date': '2020-02-24 05:05:43',
#   'Lat': 63.05,
#   'Lng': 179.32,
#   'Max Temp': -4.81,
#   'Humidity': 97,
#   'Cloudiness': 76,
#   'Wind Speed': 8.79,
#   'Current Description': 'light snow',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0.13},
#  {'City': 'Busselton',
#   'Country': 'AU',
#   'Date': '2020-02-24 05:05:43',
#   'Lat': -33.65,
#   'Lng': 115.33,
#   'Max Temp': 80.01,
#   'Humidity': 33,
#   'Cloudiness': 99,
#   'Wind Speed': 13.78,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Goderich',
#   'Country': 'CA',
#   'Date': '2020-02-24 05:05:43',
#   'Lat': 43.75,
#   'Lng': -81.72,
#   'Max Temp': 42.01,
#   'Humidity': 70,
#   'Cloudiness': 0,
#   'Wind Speed': 10.96,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Maragogi',
#   'Country': 'BR',
#   'Date': '2020-02-24 05:05:43',
#   'Lat': -9.01,
#   'Lng': -35.22,
#   'Max Temp': 81.66,
#   'Humidity': 78,
#   'Cloudiness': 66,
#   'Wind Speed': 14.29,
#   'Current Description': 'light rain',
#   'Rain inches (last 3 hrs)': 0.5,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Ruidoso',
#   'Country': 'US',
#   'Date': '2020-02-24 05:05:44',
#   'Lat': 33.33,
#   'Lng': -105.67,
#   'Max Temp': 51.8,
#   'Humidity': 55,
#   'Cloudiness': 1,
#   'Wind Speed': 12.75,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Yellowknife',
#   'Country': 'CA',
#   'Date': '2020-02-24 05:05:44',
#   'Lat': 62.46,
#   'Lng': -114.35,
#   'Max Temp': -9.4,
#   'Humidity': 69,
#   'Cloudiness': 5,
#   'Wind Speed': 8.05,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Balta',
#   'Country': 'UA',
#   'Date': '2020-02-24 05:05:44',
#   'Lat': 47.94,
#   'Lng': 29.62,
#   'Max Temp': 46.02,
#   'Humidity': 65,
#   'Cloudiness': 99,
#   'Wind Speed': 27.58,
#   'Current Description': 'light rain',
#   'Rain inches (last 3 hrs)': 1.25,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Lukulu',
#   'Country': 'ZM',
#   'Date': '2020-02-24 05:05:44',
#   'Lat': -14.37,
#   'Lng': 23.24,
#   'Max Temp': 68.27,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 6.82,
#   'Current Description': 'moderate rain',
#   'Rain inches (last 3 hrs)': 7.81,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Sinnamary',
#   'Country': 'GF',
#   'Date': '2020-02-24 05:05:45',
#   'Lat': 5.38,
#   'Lng': -52.95,
#   'Max Temp': 78.26,
#   'Humidity': 84,
#   'Cloudiness': 99,
#   'Wind Speed': 17.18,
#   'Current Description': 'light rain',
#   'Rain inches (last 3 hrs)': 0.38,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Ahuimanu',
#   'Country': 'US',
#   'Date': '2020-02-24 05:05:45',
#   'Lat': 21.44,
#   'Lng': -157.84,
#   'Max Temp': 80.6,
#   'Humidity': 73,
#   'Cloudiness': 20,
#   'Wind Speed': 11.41,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Mys Shmidta',
#   'Country': 'US',
#   'Date': '2020-02-24 05:05:45',
#   'Lat': 21.44,
#   'Lng': -157.84,
#   'Max Temp': 80.6,
#   'Humidity': 73,
#   'Cloudiness': 20,
#   'Wind Speed': 11.41,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Lagoa',
#   'Country': 'PT',
#   'Date': '2020-02-24 05:05:45',
#   'Lat': 39.05,
#   'Lng': -27.98,
#   'Max Temp': 59.65,
#   'Humidity': 81,
#   'Cloudiness': 89,
#   'Wind Speed': 11.65,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Ixtapa',
#   'Country': 'MX',
#   'Date': '2020-02-24 05:05:45',
#   'Lat': 20.7,
#   'Lng': -105.2,
#   'Max Temp': 73,
#   'Humidity': 94,
#   'Cloudiness': 5,
#   'Wind Speed': 2.24,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Airai',
#   'Country': 'TL',
#   'Date': '2020-02-24 05:05:46',
#   'Lat': -8.93,
#   'Lng': 125.41,
#   'Max Temp': 79.25,
#   'Humidity': 69,
#   'Cloudiness': 58,
#   'Wind Speed': 1.83,
#   'Current Description': 'light rain',
#   'Rain inches (last 3 hrs)': 2.19,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Leshukonskoye',
#   'Country': 'RU',
#   'Date': '2020-02-24 05:05:46',
#   'Lat': 64.9,
#   'Lng': 45.76,
#   'Max Temp': 30.22,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 13.29,
#   'Current Description': 'light snow',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0.19},
#  {'City': 'Punta Arenas',
#   'Country': 'CL',
#   'Date': '2020-02-24 05:04:32',
#   'Lat': -53.15,
#   'Lng': -70.92,
#   'Max Temp': 44.6,
#   'Humidity': 75,
#   'Cloudiness': 75,
#   'Wind Speed': 19.46,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Ribeira Grande',
#   'Country': 'PT',
#   'Date': '2020-02-24 05:05:46',
#   'Lat': 38.52,
#   'Lng': -28.7,
#   'Max Temp': 55.4,
#   'Humidity': 84,
#   'Cloudiness': 90,
#   'Wind Speed': 8.21,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Hobart',
#   'Country': 'AU',
#   'Date': '2020-02-24 05:03:37',
#   'Lat': -42.88,
#   'Lng': 147.33,
#   'Max Temp': 72,
#   'Humidity': 56,
#   'Cloudiness': 75,
#   'Wind Speed': 12.75,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Necochea',
#   'Country': 'AR',
#   'Date': '2020-02-24 05:05:47',
#   'Lat': -38.55,
#   'Lng': -58.74,
#   'Max Temp': 61,
#   'Humidity': 79,
#   'Cloudiness': 0,
#   'Wind Speed': 14,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Khatanga',
#   'Country': 'RU',
#   'Date': '2020-02-24 05:04:39',
#   'Lat': 71.97,
#   'Lng': 102.5,
#   'Max Temp': 20.1,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 18.43,
#   'Current Description': 'light snow',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0.5},
#  {'City': 'Baijiantan',
#   'Country': 'CN',
#   'Date': '2020-02-24 05:05:47',
#   'Lat': 45.63,
#   'Lng': 85.18,
#   'Max Temp': 27.43,
#   'Humidity': 85,
#   'Cloudiness': 98,
#   'Wind Speed': 7.31,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Chodavaram',
#   'Country': 'IN',
#   'Date': '2020-02-24 05:05:48',
#   'Lat': 17.83,
#   'Lng': 82.95,
#   'Max Temp': 82.4,
#   'Humidity': 61,
#   'Cloudiness': 25,
#   'Wind Speed': 4.7,
#   'Current Description': 'haze',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Juneau',
#   'Country': 'US',
#   'Date': '2020-02-24 05:05:48',
#   'Lat': 58.3,
#   'Lng': -134.42,
#   'Max Temp': 34,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 7.99,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Walvis Bay',
#   'Country': 'NA',
#   'Date': '2020-02-24 05:05:48',
#   'Lat': -22.96,
#   'Lng': 14.51,
#   'Max Temp': 64.4,
#   'Humidity': 88,
#   'Cloudiness': 47,
#   'Wind Speed': 10.29,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Maroua',
#   'Country': 'CM',
#   'Date': '2020-02-24 05:05:48',
#   'Lat': 10.59,
#   'Lng': 14.32,
#   'Max Temp': 65.8,
#   'Humidity': 25,
#   'Cloudiness': 0,
#   'Wind Speed': 10.56,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Iqaluit',
#   'Country': 'CA',
#   'Date': '2020-02-24 05:05:48',
#   'Lat': 63.75,
#   'Lng': -68.51,
#   'Max Temp': -25.01,
#   'Humidity': 67,
#   'Cloudiness': 40,
#   'Wind Speed': 4.99,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'San Quintin',
#   'Country': 'MX',
#   'Date': '2020-02-24 05:05:49',
#   'Lat': 30.48,
#   'Lng': -115.95,
#   'Max Temp': 56.64,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 11.18,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Mangrol',
#   'Country': 'IN',
#   'Date': '2020-02-24 05:05:49',
#   'Lat': 21.12,
#   'Lng': 70.12,
#   'Max Temp': 79.92,
#   'Humidity': 54,
#   'Cloudiness': 0,
#   'Wind Speed': 7.85,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Kamenka',
#   'Country': 'RU',
#   'Date': '2020-02-24 05:05:49',
#   'Lat': 51.32,
#   'Lng': 42.77,
#   'Max Temp': 34,
#   'Humidity': 98,
#   'Cloudiness': 87,
#   'Wind Speed': 5.01,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Oakham',
#   'Country': 'GB',
#   'Date': '2020-02-24 05:05:49',
#   'Lat': 52.67,
#   'Lng': -0.73,
#   'Max Temp': 42.01,
#   'Humidity': 75,
#   'Cloudiness': 75,
#   'Wind Speed': 17.22,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Fortuna',
#   'Country': 'US',
#   'Date': '2020-02-24 05:05:50',
#   'Lat': 40.6,
#   'Lng': -124.16,
#   'Max Temp': 48.2,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Nishihara',
#   'Country': 'JP',
#   'Date': '2020-02-24 05:05:50',
#   'Lat': 26.18,
#   'Lng': 127.76,
#   'Max Temp': 73,
#   'Humidity': 56,
#   'Cloudiness': 20,
#   'Wind Speed': 10.29,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Riyadh',
#   'Country': 'SA',
#   'Date': '2020-02-24 05:02:47',
#   'Lat': 24.69,
#   'Lng': 46.72,
#   'Max Temp': 66.2,
#   'Humidity': 72,
#   'Cloudiness': 40,
#   'Wind Speed': 3.36,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Farafangana',
#   'Country': 'MG',
#   'Date': '2020-02-24 05:05:50',
#   'Lat': -22.82,
#   'Lng': 47.83,
#   'Max Temp': 79.84,
#   'Humidity': 84,
#   'Cloudiness': 48,
#   'Wind Speed': 11.61,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Longyearbyen',
#   'Country': 'SJ',
#   'Date': '2020-02-24 05:05:50',
#   'Lat': 78.22,
#   'Lng': 15.64,
#   'Max Temp': -4,
#   'Humidity': 76,
#   'Cloudiness': 40,
#   'Wind Speed': 3.36,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Awbari',
#   'Country': 'LY',
#   'Date': '2020-02-24 05:05:51',
#   'Lat': 26.59,
#   'Lng': 12.78,
#   'Max Temp': 43.68,
#   'Humidity': 67,
#   'Cloudiness': 0,
#   'Wind Speed': 3.53,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Katsuura',
#   'Country': 'JP',
#   'Date': '2020-02-24 05:05:51',
#   'Lat': 35.13,
#   'Lng': 140.3,
#   'Max Temp': 61,
#   'Humidity': 44,
#   'Cloudiness': 20,
#   'Wind Speed': 9.17,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Vaini',
#   'Country': 'TO',
#   'Date': '2020-02-24 05:05:51',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 78.8,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 4.7,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Kodiak',
#   'Country': 'US',
#   'Date': '2020-02-24 05:05:51',
#   'Lat': 57.79,
#   'Lng': -152.41,
#   'Max Temp': 24.8,
#   'Humidity': 41,
#   'Cloudiness': 1,
#   'Wind Speed': 13.87,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Hasaki',
#   'Country': 'JP',
#   'Date': '2020-02-24 05:01:49',
#   'Lat': 35.73,
#   'Lng': 140.83,
#   'Max Temp': 63,
#   'Humidity': 38,
#   'Cloudiness': 20,
#   'Wind Speed': 5.82,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Panalingaan',
#   'Country': 'PH',
#   'Date': '2020-02-24 05:05:52',
#   'Lat': 8.78,
#   'Lng': 117.42,
#   'Max Temp': 83.86,
#   'Humidity': 69,
#   'Cloudiness': 60,
#   'Wind Speed': 14.63,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Bonthe',
#   'Country': 'SL',
#   'Date': '2020-02-24 05:05:52',
#   'Lat': 7.53,
#   'Lng': -12.51,
#   'Max Temp': 77.67,
#   'Humidity': 82,
#   'Cloudiness': 75,
#   'Wind Speed': 3.69,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Castro',
#   'Country': 'BR',
#   'Date': '2020-02-24 05:05:52',
#   'Lat': -24.79,
#   'Lng': -50.01,
#   'Max Temp': 57.63,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 8.12,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Eureka',
#   'Country': 'US',
#   'Date': '2020-02-24 05:05:52',
#   'Lat': 40.8,
#   'Lng': -124.16,
#   'Max Temp': 48.2,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Marzuq',
#   'Country': 'YE',
#   'Date': '2020-02-24 05:05:53',
#   'Lat': 14.4,
#   'Lng': 46.47,
#   'Max Temp': 76.1,
#   'Humidity': 8,
#   'Cloudiness': 27,
#   'Wind Speed': 2.86,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Kapaa',
#   'Country': 'US',
#   'Date': '2020-02-24 05:04:44',
#   'Lat': 22.08,
#   'Lng': -159.32,
#   'Max Temp': 78.8,
#   'Humidity': 69,
#   'Cloudiness': 20,
#   'Wind Speed': 10.29,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Yushu',
#   'Country': 'CN',
#   'Date': '2020-02-24 05:05:53',
#   'Lat': 44.8,
#   'Lng': 126.53,
#   'Max Temp': 23.88,
#   'Humidity': 84,
#   'Cloudiness': 0,
#   'Wind Speed': 7.87,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Tuktoyaktuk',
#   'Country': 'CA',
#   'Date': '2020-02-24 05:04:33',
#   'Lat': 69.45,
#   'Lng': -133.04,
#   'Max Temp': -11.2,
#   'Humidity': 76,
#   'Cloudiness': 75,
#   'Wind Speed': 13.87,
#   'Current Description': 'light snow',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Port Blair',
#   'Country': 'IN',
#   'Date': '2020-02-24 05:03:16',
#   'Lat': 11.67,
#   'Lng': 92.75,
#   'Max Temp': 82,
#   'Humidity': 73,
#   'Cloudiness': 19,
#   'Wind Speed': 13.73,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Raudeberg',
#   'Country': 'NO',
#   'Date': '2020-02-24 05:05:54',
#   'Lat': 61.99,
#   'Lng': 5.14,
#   'Max Temp': 35.6,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 18.34,
#   'Current Description': 'snow',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 2.81},
#  {'City': 'Libenge',
#   'Country': 'CD',
#   'Date': '2020-02-24 05:05:54',
#   'Lat': 3.65,
#   'Lng': 18.63,
#   'Max Temp': 74.8,
#   'Humidity': 66,
#   'Cloudiness': 65,
#   'Wind Speed': 4.03,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Hithadhoo',
#   'Country': 'MV',
#   'Date': '2020-02-24 05:02:43',
#   'Lat': -0.6,
#   'Lng': 73.08,
#   'Max Temp': 83.39,
#   'Humidity': 78,
#   'Cloudiness': 39,
#   'Wind Speed': 12.15,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Porkhov',
#   'Country': 'RU',
#   'Date': '2020-02-24 05:05:54',
#   'Lat': 57.77,
#   'Lng': 29.56,
#   'Max Temp': 33.8,
#   'Humidity': 88,
#   'Cloudiness': 59,
#   'Wind Speed': 8.95,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Saint-Philippe',
#   'Country': 'RE',
#   'Date': '2020-02-24 05:05:55',
#   'Lat': -21.36,
#   'Lng': 55.77,
#   'Max Temp': 84.99,
#   'Humidity': 58,
#   'Cloudiness': 45,
#   'Wind Speed': 2.24,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Illoqqortoormiut',
#   'Country': 'RE',
#   'Date': '2020-02-24 05:05:55',
#   'Lat': -21.36,
#   'Lng': 55.77,
#   'Max Temp': 84.99,
#   'Humidity': 58,
#   'Cloudiness': 45,
#   'Wind Speed': 2.24,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Makhachkala',
#   'Country': 'RU',
#   'Date': '2020-02-24 05:05:55',
#   'Lat': 42.98,
#   'Lng': 47.5,
#   'Max Temp': 37.4,
#   'Humidity': 86,
#   'Cloudiness': 90,
#   'Wind Speed': 2.24,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Arraial Do Cabo',
#   'Country': 'BR',
#   'Date': '2020-02-24 05:05:55',
#   'Lat': -22.97,
#   'Lng': -42.03,
#   'Max Temp': 73.99,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 4.85,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Benghazi',
#   'Country': 'LY',
#   'Date': '2020-02-24 05:05:55',
#   'Lat': 32.12,
#   'Lng': 20.07,
#   'Max Temp': 57.04,
#   'Humidity': 66,
#   'Cloudiness': 22,
#   'Wind Speed': 13.38,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Wageningen',
#   'Country': 'NL',
#   'Date': '2020-02-24 05:05:56',
#   'Lat': 51.97,
#   'Lng': 5.67,
#   'Max Temp': 42.01,
#   'Humidity': 86,
#   'Cloudiness': 90,
#   'Wind Speed': 6.93,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Novyy Urgal',
#   'Country': 'RU',
#   'Date': '2020-02-24 05:05:56',
#   'Lat': 51.07,
#   'Lng': 132.56,
#   'Max Temp': 13.53,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 3.53,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Bredasdorp',
#   'Country': 'ZA',
#   'Date': '2020-02-24 05:04:31',
#   'Lat': -34.53,
#   'Lng': 20.04,
#   'Max Temp': 63,
#   'Humidity': 87,
#   'Cloudiness': 0,
#   'Wind Speed': 6.93,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Guayaramerin',
#   'Country': 'BO',
#   'Date': '2020-02-24 05:05:56',
#   'Lat': -10.84,
#   'Lng': -65.36,
#   'Max Temp': 70.12,
#   'Humidity': 84,
#   'Cloudiness': 58,
#   'Wind Speed': 1.74,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Burnie',
#   'Country': 'AU',
#   'Date': '2020-02-24 05:05:42',
#   'Lat': -41.07,
#   'Lng': 145.92,
#   'Max Temp': 69.01,
#   'Humidity': 66,
#   'Cloudiness': 92,
#   'Wind Speed': 8.99,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Port Hawkesbury',
#   'Country': 'CA',
#   'Date': '2020-02-24 05:05:57',
#   'Lat': 45.62,
#   'Lng': -61.35,
#   'Max Temp': 32,
#   'Humidity': 93,
#   'Cloudiness': 1,
#   'Wind Speed': 10.29,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Amderma',
#   'Country': 'CA',
#   'Date': '2020-02-24 05:05:57',
#   'Lat': 45.62,
#   'Lng': -61.35,
#   'Max Temp': 32,
#   'Humidity': 93,
#   'Cloudiness': 1,
#   'Wind Speed': 10.29,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Ati',
#   'Country': 'TD',
#   'Date': '2020-02-24 05:02:05',
#   'Lat': 13.22,
#   'Lng': 18.34,
#   'Max Temp': 66.18,
#   'Humidity': 25,
#   'Cloudiness': 0,
#   'Wind Speed': 16.22,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Ulladulla',
#   'Country': 'AU',
#   'Date': '2020-02-24 05:05:58',
#   'Lat': -35.35,
#   'Lng': 150.47,
#   'Max Temp': 82.99,
#   'Humidity': 48,
#   'Cloudiness': 20,
#   'Wind Speed': 17.22,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Carnarvon',
#   'Country': 'AU',
#   'Date': '2020-02-24 05:02:27',
#   'Lat': -24.87,
#   'Lng': 113.63,
#   'Max Temp': 84.2,
#   'Humidity': 58,
#   'Cloudiness': 0,
#   'Wind Speed': 12.75,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Vao',
#   'Country': 'NC',
#   'Date': '2020-02-24 05:05:58',
#   'Lat': -22.67,
#   'Lng': 167.48,
#   'Max Temp': 78.82,
#   'Humidity': 72,
#   'Cloudiness': 71,
#   'Wind Speed': 14.16,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Kapoeta',
#   'Country': 'SS',
#   'Date': '2020-02-24 05:05:58',
#   'Lat': 4.77,
#   'Lng': 33.59,
#   'Max Temp': 90.34,
#   'Humidity': 26,
#   'Cloudiness': 32,
#   'Wind Speed': 9.66,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Sanary-Sur-Mer',
#   'Country': 'FR',
#   'Date': '2020-02-24 05:05:58',
#   'Lat': 43.12,
#   'Lng': 5.8,
#   'Max Temp': 57,
#   'Humidity': 93,
#   'Cloudiness': 0,
#   'Wind Speed': 1.12,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Marovoay',
#   'Country': 'MG',
#   'Date': '2020-02-24 05:05:59',
#   'Lat': -16.1,
#   'Lng': 46.63,
#   'Max Temp': 78.8,
#   'Humidity': 94,
#   'Cloudiness': 20,
#   'Wind Speed': 5.82,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Atar',
#   'Country': 'MR',
#   'Date': '2020-02-24 05:05:59',
#   'Lat': 20.52,
#   'Lng': -13.05,
#   'Max Temp': 74.16,
#   'Humidity': 23,
#   'Cloudiness': 97,
#   'Wind Speed': 7.45,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Thompson',
#   'Country': 'CA',
#   'Date': '2020-02-24 05:02:58',
#   'Lat': 55.74,
#   'Lng': -97.86,
#   'Max Temp': 10.4,
#   'Humidity': 78,
#   'Cloudiness': 90,
#   'Wind Speed': 6.93,
#   'Current Description': 'light snow',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Belaya Gora',
#   'Country': 'RU',
#   'Date': '2020-02-24 05:05:59',
#   'Lat': 68.53,
#   'Lng': 146.42,
#   'Max Temp': -14.89,
#   'Humidity': 98,
#   'Cloudiness': 98,
#   'Wind Speed': 3.94,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Torbay',
#   'Country': 'CA',
#   'Date': '2020-02-24 05:04:50',
#   'Lat': 47.67,
#   'Lng': -52.73,
#   'Max Temp': 28.99,
#   'Humidity': 86,
#   'Cloudiness': 40,
#   'Wind Speed': 20.8,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'El Tigre',
#   'Country': 'VE',
#   'Date': '2020-02-24 05:06:00',
#   'Lat': 8.89,
#   'Lng': -64.25,
#   'Max Temp': 75.56,
#   'Humidity': 80,
#   'Cloudiness': 62,
#   'Wind Speed': 12.53,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Beyla',
#   'Country': 'GN',
#   'Date': '2020-02-24 05:06:00',
#   'Lat': 8.68,
#   'Lng': -8.63,
#   'Max Temp': 67.62,
#   'Humidity': 92,
#   'Cloudiness': 34,
#   'Wind Speed': 3.44,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Prince Rupert',
#   'Country': 'CA',
#   'Date': '2020-02-24 05:06:00',
#   'Lat': 54.32,
#   'Lng': -130.32,
#   'Max Temp': 35.6,
#   'Humidity': 69,
#   'Cloudiness': 90,
#   'Wind Speed': 9.17,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Qaanaaq',
#   'Country': 'GL',
#   'Date': '2020-02-24 05:06:00',
#   'Lat': 77.48,
#   'Lng': -69.36,
#   'Max Temp': -16.91,
#   'Humidity': 54,
#   'Cloudiness': 0,
#   'Wind Speed': 5.46,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Campos Do Jordao',
#   'Country': 'BR',
#   'Date': '2020-02-24 05:06:01',
#   'Lat': -22.74,
#   'Lng': -45.59,
#   'Max Temp': 66.2,
#   'Humidity': 82,
#   'Cloudiness': 75,
#   'Wind Speed': 3.36,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Hihifo',
#   'Country': 'BR',
#   'Date': '2020-02-24 05:06:01',
#   'Lat': -22.74,
#   'Lng': -45.59,
#   'Max Temp': 66.2,
#   'Humidity': 82,
#   'Cloudiness': 75,
#   'Wind Speed': 3.36,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Salina',
#   'Country': 'US',
#   'Date': '2020-02-24 05:01:52',
#   'Lat': 38.84,
#   'Lng': -97.61,
#   'Max Temp': 48,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 9.17,
#   'Current Description': 'moderate rain',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Nago',
#   'Country': 'JP',
#   'Date': '2020-02-24 05:06:01',
#   'Lat': 26.59,
#   'Lng': 127.98,
#   'Max Temp': 73,
#   'Humidity': 56,
#   'Cloudiness': 20,
#   'Wind Speed': 10.29,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Marawi',
#   'Country': 'PH',
#   'Date': '2020-02-24 05:06:01',
#   'Lat': 8,
#   'Lng': 124.29,
#   'Max Temp': 82.99,
#   'Humidity': 78,
#   'Cloudiness': 32,
#   'Wind Speed': 7,
#   'Current Description': 'light rain',
#   'Rain inches (last 3 hrs)': 0.13,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Lima',
#   'Country': 'PE',
#   'Date': '2020-02-24 05:05:39',
#   'Lat': -12.04,
#   'Lng': -77.03,
#   'Max Temp': 75.2,
#   'Humidity': 88,
#   'Cloudiness': 50,
#   'Wind Speed': 10.29,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Tatawin',
#   'Country': 'TN',
#   'Date': '2020-02-24 05:06:02',
#   'Lat': 32.93,
#   'Lng': 10.45,
#   'Max Temp': 46.4,
#   'Humidity': 81,
#   'Cloudiness': 3,
#   'Wind Speed': 3.36,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Slave Lake',
#   'Country': 'CA',
#   'Date': '2020-02-24 05:06:02',
#   'Lat': 55.28,
#   'Lng': -114.77,
#   'Max Temp': 15.8,
#   'Humidity': 85,
#   'Cloudiness': 1,
#   'Wind Speed': 4.7,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Antsohihy',
#   'Country': 'MG',
#   'Date': '2020-02-24 05:06:02',
#   'Lat': -14.88,
#   'Lng': 47.99,
#   'Max Temp': 84.52,
#   'Humidity': 77,
#   'Cloudiness': 74,
#   'Wind Speed': 1.74,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Cachoeira Do Sul',
#   'Country': 'BR',
#   'Date': '2020-02-24 05:06:03',
#   'Lat': -30.04,
#   'Lng': -52.89,
#   'Max Temp': 58.44,
#   'Humidity': 97,
#   'Cloudiness': 0,
#   'Wind Speed': 4.32,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Guanica',
#   'Country': 'PR',
#   'Date': '2020-02-24 05:06:03',
#   'Lat': 17.97,
#   'Lng': -66.91,
#   'Max Temp': 75,
#   'Humidity': 73,
#   'Cloudiness': 1,
#   'Wind Speed': 4.29,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Maceio',
#   'Country': 'BR',
#   'Date': '2020-02-24 05:05:12',
#   'Lat': -9.67,
#   'Lng': -35.74,
#   'Max Temp': 77,
#   'Humidity': 94,
#   'Cloudiness': 20,
#   'Wind Speed': 3.36,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Erenhot',
#   'Country': 'CN',
#   'Date': '2020-02-24 05:06:03',
#   'Lat': 43.65,
#   'Lng': 111.98,
#   'Max Temp': 28.4,
#   'Humidity': 73,
#   'Cloudiness': 88,
#   'Wind Speed': 14.67,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Nome',
#   'Country': 'US',
#   'Date': '2020-02-24 05:06:03',
#   'Lat': 64.5,
#   'Lng': -165.41,
#   'Max Temp': 3.2,
#   'Humidity': 84,
#   'Cloudiness': 90,
#   'Wind Speed': 6.93,
#   'Current Description': 'light snow',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Albany',
#   'Country': 'US',
#   'Date': '2020-02-24 05:01:39',
#   'Lat': 42.6,
#   'Lng': -73.97,
#   'Max Temp': 33.01,
#   'Humidity': 68,
#   'Cloudiness': 1,
#   'Wind Speed': 5.82,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Dikson',
#   'Country': 'RU',
#   'Date': '2020-02-24 05:06:04',
#   'Lat': 73.51,
#   'Lng': 80.55,
#   'Max Temp': 22.77,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 26.11,
#   'Current Description': 'light snow',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0.19},
#  {'City': 'Upernavik',
#   'Country': 'GL',
#   'Date': '2020-02-24 05:06:04',
#   'Lat': 72.79,
#   'Lng': -56.15,
#   'Max Temp': -20.83,
#   'Humidity': 87,
#   'Cloudiness': 16,
#   'Wind Speed': 4.12,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Sayanogorsk',
#   'Country': 'RU',
#   'Date': '2020-02-24 05:06:04',
#   'Lat': 53.09,
#   'Lng': 91.4,
#   'Max Temp': 19.47,
#   'Humidity': 88,
#   'Cloudiness': 95,
#   'Wind Speed': 4.12,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Iberia',
#   'Country': 'US',
#   'Date': '2020-02-24 05:06:05',
#   'Lat': 29.95,
#   'Lng': -91.75,
#   'Max Temp': 60.8,
#   'Humidity': 77,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Yerbogachen',
#   'Country': 'RU',
#   'Date': '2020-02-24 05:06:05',
#   'Lat': 61.28,
#   'Lng': 108.01,
#   'Max Temp': 20.01,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 13.98,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'El Alto',
#   'Country': 'PE',
#   'Date': '2020-02-24 05:06:05',
#   'Lat': -4.27,
#   'Lng': -81.21,
#   'Max Temp': 74.77,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 4.97,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Chokurdakh',
#   'Country': 'RU',
#   'Date': '2020-02-24 05:06:05',
#   'Lat': 70.63,
#   'Lng': 147.92,
#   'Max Temp': -23.26,
#   'Humidity': 98,
#   'Cloudiness': 56,
#   'Wind Speed': 3.51,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Barentsburg',
#   'Country': 'RU',
#   'Date': '2020-02-24 05:06:05',
#   'Lat': 70.63,
#   'Lng': 147.92,
#   'Max Temp': -23.26,
#   'Humidity': 98,
#   'Cloudiness': 56,
#   'Wind Speed': 3.51,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Kenai',
#   'Country': 'US',
#   'Date': '2020-02-24 05:06:06',
#   'Lat': 60.55,
#   'Lng': -151.26,
#   'Max Temp': 8.6,
#   'Humidity': 78,
#   'Cloudiness': 1,
#   'Wind Speed': 5.82,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Opuwo',
#   'Country': 'NA',
#   'Date': '2020-02-24 05:06:06',
#   'Lat': -18.06,
#   'Lng': 13.84,
#   'Max Temp': 68.74,
#   'Humidity': 37,
#   'Cloudiness': 30,
#   'Wind Speed': 4.76,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Beloha',
#   'Country': 'MG',
#   'Date': '2020-02-24 05:06:06',
#   'Lat': -25.17,
#   'Lng': 45.05,
#   'Max Temp': 77.31,
#   'Humidity': 84,
#   'Cloudiness': 81,
#   'Wind Speed': 2.89,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Bereda',
#   'Country': 'ES',
#   'Date': '2020-02-24 05:06:06',
#   'Lat': 43.27,
#   'Lng': -7.54,
#   'Max Temp': 48,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 2.24,
#   'Current Description': 'fog',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Narsaq',
#   'Country': 'GL',
#   'Date': '2020-02-24 05:03:04',
#   'Lat': 60.92,
#   'Lng': -46.05,
#   'Max Temp': 21.2,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 4.7,
#   'Current Description': 'light snow',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Milak',
#   'Country': 'IN',
#   'Date': '2020-02-24 05:06:07',
#   'Lat': 28.62,
#   'Lng': 79.18,
#   'Max Temp': 74.71,
#   'Humidity': 46,
#   'Cloudiness': 0,
#   'Wind Speed': 3.29,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Napuro',
#   'Country': 'PH',
#   'Date': '2020-02-24 05:06:07',
#   'Lat': 12.03,
#   'Lng': 124.71,
#   'Max Temp': 85.48,
#   'Humidity': 62,
#   'Cloudiness': 0,
#   'Wind Speed': 9.69,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'East London',
#   'Country': 'ZA',
#   'Date': '2020-02-24 05:06:07',
#   'Lat': -33.02,
#   'Lng': 27.91,
#   'Max Temp': 59,
#   'Humidity': 82,
#   'Cloudiness': 15,
#   'Wind Speed': 5.82,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Satitoa',
#   'Country': 'ZA',
#   'Date': '2020-02-24 05:06:07',
#   'Lat': -33.02,
#   'Lng': 27.91,
#   'Max Temp': 59,
#   'Humidity': 82,
#   'Cloudiness': 15,
#   'Wind Speed': 5.82,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Lavrentiya',
#   'Country': 'RU',
#   'Date': '2020-02-24 05:06:08',
#   'Lat': 65.58,
#   'Lng': -171,
#   'Max Temp': -9.27,
#   'Humidity': 75,
#   'Cloudiness': 0,
#   'Wind Speed': 3.36,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Kamphaeng Phet',
#   'Country': 'TH',
#   'Date': '2020-02-24 05:06:08',
#   'Lat': 16.48,
#   'Lng': 99.52,
#   'Max Temp': 91.99,
#   'Humidity': 34,
#   'Cloudiness': 4,
#   'Wind Speed': 10.16,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Bangui',
#   'Country': 'CF',
#   'Date': '2020-02-24 05:06:08',
#   'Lat': 4.36,
#   'Lng': 18.55,
#   'Max Temp': 78.8,
#   'Humidity': 88,
#   'Cloudiness': 47,
#   'Wind Speed': 1.68,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Chengmai',
#   'Country': 'CF',
#   'Date': '2020-02-24 05:06:08',
#   'Lat': 4.36,
#   'Lng': 18.55,
#   'Max Temp': 78.8,
#   'Humidity': 88,
#   'Cloudiness': 47,
#   'Wind Speed': 1.68,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Suez',
#   'Country': 'EG',
#   'Date': '2020-02-24 05:01:31',
#   'Lat': 29.97,
# ...
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Vokhtoga',
#   'Country': 'RU',
#   'Date': '2020-02-24 05:07:43',
#   'Lat': 58.81,
#   'Lng': 41.05,
#   'Max Temp': 33.04,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 9.8,
#   'Current Description': 'light snow',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 1.19},
#  {'City': 'Ipixuna',
#   'Country': 'BR',
#   'Date': '2020-02-24 05:07:43',
#   'Lat': -1.76,
#   'Lng': -48.8,
#   'Max Temp': 78.8,
#   'Humidity': 88,
#   'Cloudiness': 40,
#   'Wind Speed': 6.93,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Castanhal',
#   'Country': 'BR',
#   'Date': '2020-02-24 05:07:44',
#   'Lat': -1.29,
#   'Lng': -47.93,
#   'Max Temp': 78.8,
#   'Humidity': 88,
#   'Cloudiness': 40,
#   'Wind Speed': 6.93,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Angoram',
#   'Country': 'PG',
#   'Date': '2020-02-24 05:07:44',
#   'Lat': -4.06,
#   'Lng': 144.07,
#   'Max Temp': 87.17,
#   'Humidity': 63,
#   'Cloudiness': 100,
#   'Wind Speed': 5.53,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Shunyi',
#   'Country': 'CN',
#   'Date': '2020-02-24 05:07:00',
#   'Lat': 40.12,
#   'Lng': 116.65,
#   'Max Temp': 55.99,
#   'Humidity': 36,
#   'Cloudiness': 100,
#   'Wind Speed': 4.47,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Junin',
#   'Country': 'AR',
#   'Date': '2020-02-24 05:07:44',
#   'Lat': -34.58,
#   'Lng': -60.94,
#   'Max Temp': 57,
#   'Humidity': 93,
#   'Cloudiness': 2,
#   'Wind Speed': 1.99,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Inhambane',
#   'Country': 'MZ',
#   'Date': '2020-02-24 05:07:44',
#   'Lat': -23.86,
#   'Lng': 35.38,
#   'Max Temp': 77,
#   'Humidity': 69,
#   'Cloudiness': 75,
#   'Wind Speed': 16.11,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Penzance',
#   'Country': 'GB',
#   'Date': '2020-02-24 05:07:45',
#   'Lat': 50.12,
#   'Lng': -5.54,
#   'Max Temp': 52,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 28.86,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Lufilufi',
#   'Country': 'WS',
#   'Date': '2020-02-24 05:07:45',
#   'Lat': -13.87,
#   'Lng': -171.6,
#   'Max Temp': 86,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 3,
#   'Current Description': 'light rain',
#   'Rain inches (last 3 hrs)': 2.44,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Faya',
#   'Country': 'SA',
#   'Date': '2020-02-24 05:07:45',
#   'Lat': 18.39,
#   'Lng': 42.45,
#   'Max Temp': 57.2,
#   'Humidity': 87,
#   'Cloudiness': 20,
#   'Wind Speed': 4.7,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Okhotsk',
#   'Country': 'RU',
#   'Date': '2020-02-24 05:07:45',
#   'Lat': 59.38,
#   'Lng': 143.3,
#   'Max Temp': -2.16,
#   'Humidity': 79,
#   'Cloudiness': 69,
#   'Wind Speed': 5.3,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Kamenskoye',
#   'Country': 'RU',
#   'Date': '2020-02-24 05:07:45',
#   'Lat': 59.38,
#   'Lng': 143.3,
#   'Max Temp': -2.16,
#   'Humidity': 79,
#   'Cloudiness': 69,
#   'Wind Speed': 5.3,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Tuatapere',
#   'Country': 'NZ',
#   'Date': '2020-02-24 05:07:46',
#   'Lat': -46.13,
#   'Lng': 167.68,
#   'Max Temp': 64.99,
#   'Humidity': 63,
#   'Cloudiness': 26,
#   'Wind Speed': 14,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Andenes',
#   'Country': 'NO',
#   'Date': '2020-02-24 05:07:46',
#   'Lat': 69.31,
#   'Lng': 16.12,
#   'Max Temp': 32,
#   'Humidity': 66,
#   'Cloudiness': 75,
#   'Wind Speed': 26.4,
#   'Current Description': 'light shower snow',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Natalio',
#   'Country': 'PY',
#   'Date': '2020-02-24 05:07:46',
#   'Lat': -26.72,
#   'Lng': -55.08,
#   'Max Temp': 63.45,
#   'Humidity': 96,
#   'Cloudiness': 34,
#   'Wind Speed': 1.16,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Hare Bay',
#   'Country': 'CA',
#   'Date': '2020-02-24 05:07:46',
#   'Lat': 48.85,
#   'Lng': -54.01,
#   'Max Temp': 24.8,
#   'Humidity': 79,
#   'Cloudiness': 20,
#   'Wind Speed': 13.87,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Belawan',
#   'Country': 'ID',
#   'Date': '2020-02-24 05:07:47',
#   'Lat': 3.78,
#   'Lng': 98.68,
#   'Max Temp': 86,
#   'Humidity': 70,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Hamilton',
#   'Country': 'US',
#   'Date': '2020-02-24 05:03:14',
#   'Lat': 39.18,
#   'Lng': -84.53,
#   'Max Temp': 44.6,
#   'Humidity': 48,
#   'Cloudiness': 1,
#   'Wind Speed': 5.64,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Jalu',
#   'Country': 'LY',
#   'Date': '2020-02-24 05:07:47',
#   'Lat': 29.03,
#   'Lng': 21.55,
#   'Max Temp': 50.9,
#   'Humidity': 75,
#   'Cloudiness': 43,
#   'Wind Speed': 6.31,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Saint-Joseph',
#   'Country': 'RE',
#   'Date': '2020-02-24 05:07:47',
#   'Lat': -21.37,
#   'Lng': 55.62,
#   'Max Temp': 84.99,
#   'Humidity': 58,
#   'Cloudiness': 25,
#   'Wind Speed': 2.24,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Kishi',
#   'Country': 'NG',
#   'Date': '2020-02-24 05:07:48',
#   'Lat': 9.08,
#   'Lng': 3.85,
#   'Max Temp': 68.56,
#   'Humidity': 18,
#   'Cloudiness': 10,
#   'Wind Speed': 4.94,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Mayumba',
#   'Country': 'GA',
#   'Date': '2020-02-24 05:07:48',
#   'Lat': -3.43,
#   'Lng': 10.66,
#   'Max Temp': 81.52,
#   'Humidity': 79,
#   'Cloudiness': 93,
#   'Wind Speed': 6.2,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Sivaki',
#   'Country': 'RU',
#   'Date': '2020-02-24 05:07:48',
#   'Lat': 52.63,
#   'Lng': 126.75,
#   'Max Temp': 20.07,
#   'Humidity': 83,
#   'Cloudiness': 31,
#   'Wind Speed': 11.05,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Yarkovo',
#   'Country': 'RU',
#   'Date': '2020-02-24 05:07:48',
#   'Lat': 57.4,
#   'Lng': 67.08,
#   'Max Temp': 18.82,
#   'Humidity': 92,
#   'Cloudiness': 73,
#   'Wind Speed': 10.04,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Sechura',
#   'Country': 'PE',
#   'Date': '2020-02-24 05:07:48',
#   'Lat': -5.56,
#   'Lng': -80.82,
#   'Max Temp': 75.6,
#   'Humidity': 80,
#   'Cloudiness': 90,
#   'Wind Speed': 6.13,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'San Policarpo',
#   'Country': 'PH',
#   'Date': '2020-02-24 05:07:49',
#   'Lat': 12.18,
#   'Lng': 125.51,
#   'Max Temp': 81.3,
#   'Humidity': 74,
#   'Cloudiness': 18,
#   'Wind Speed': 15.08,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Pedernales',
#   'Country': 'DO',
#   'Date': '2020-02-24 05:07:49',
#   'Lat': 18.04,
#   'Lng': -71.74,
#   'Max Temp': 65.86,
#   'Humidity': 90,
#   'Cloudiness': 8,
#   'Wind Speed': 2.93,
#   'Current Description': 'light rain',
#   'Rain inches (last 3 hrs)': 0.88,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Monrovia',
#   'Country': 'LR',
#   'Date': '2020-02-24 05:07:49',
#   'Lat': 6.3,
#   'Lng': -10.8,
#   'Max Temp': 77,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 5.82,
#   'Current Description': 'mist',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Mlonggo',
#   'Country': 'ID',
#   'Date': '2020-02-24 05:07:49',
#   'Lat': -6.53,
#   'Lng': 110.7,
#   'Max Temp': 80.6,
#   'Humidity': 88,
#   'Cloudiness': 40,
#   'Wind Speed': 4.7,
#   'Current Description': 'light rain',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Manaure',
#   'Country': 'CO',
#   'Date': '2020-02-24 05:07:50',
#   'Lat': 11.78,
#   'Lng': -72.44,
#   'Max Temp': 76.12,
#   'Humidity': 87,
#   'Cloudiness': 14,
#   'Wind Speed': 12.06,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Leninskoye',
#   'Country': 'RU',
#   'Date': '2020-02-24 05:07:50',
#   'Lat': 47.94,
#   'Lng': 132.62,
#   'Max Temp': 21.87,
#   'Humidity': 83,
#   'Cloudiness': 95,
#   'Wind Speed': 5.53,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Solano',
#   'Country': 'US',
#   'Date': '2020-02-24 05:07:50',
#   'Lat': 38.23,
#   'Lng': -121.95,
#   'Max Temp': 55.4,
#   'Humidity': 87,
#   'Cloudiness': 1,
#   'Wind Speed': 4.92,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Tagusao',
#   'Country': 'PH',
#   'Date': '2020-02-24 05:07:50',
#   'Lat': 9.19,
#   'Lng': 117.81,
#   'Max Temp': 82.85,
#   'Humidity': 67,
#   'Cloudiness': 59,
#   'Wind Speed': 14.72,
#   'Current Description': 'light rain',
#   'Rain inches (last 3 hrs)': 0.31,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Mocuba',
#   'Country': 'MZ',
#   'Date': '2020-02-24 05:07:50',
#   'Lat': -16.84,
#   'Lng': 36.99,
#   'Max Temp': 78.98,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 5.08,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Shelburne',
#   'Country': 'CA',
#   'Date': '2020-02-24 05:03:54',
#   'Lat': 44.08,
#   'Lng': -80.2,
#   'Max Temp': 42.01,
#   'Humidity': 60,
#   'Cloudiness': 1,
#   'Wind Speed': 16.11,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Vallenar',
#   'Country': 'CL',
#   'Date': '2020-02-24 05:07:51',
#   'Lat': -28.57,
#   'Lng': -70.76,
#   'Max Temp': 54.86,
#   'Humidity': 88,
#   'Cloudiness': 2,
#   'Wind Speed': 1.48,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Kade',
#   'Country': 'DE',
#   'Date': '2020-02-24 05:07:51',
#   'Lat': 52.38,
#   'Lng': 12.27,
#   'Max Temp': 41,
#   'Humidity': 86,
#   'Cloudiness': 70,
#   'Wind Speed': 1.99,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Port Moresby',
#   'Country': 'PG',
#   'Date': '2020-02-24 05:07:51',
#   'Lat': -9.44,
#   'Lng': 147.18,
#   'Max Temp': 91.4,
#   'Humidity': 59,
#   'Cloudiness': 40,
#   'Wind Speed': 12.75,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Tammisaari',
#   'Country': 'FI',
#   'Date': '2020-02-24 05:07:52',
#   'Lat': 59.97,
#   'Lng': 23.43,
#   'Max Temp': 33.01,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 4,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Nakonde',
#   'Country': 'ZM',
#   'Date': '2020-02-24 05:07:52',
#   'Lat': -9.34,
#   'Lng': 32.74,
#   'Max Temp': 68.86,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 2.39,
#   'Current Description': 'light rain',
#   'Rain inches (last 3 hrs)': 1.69,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Kampong Thum',
#   'Country': 'KH',
#   'Date': '2020-02-24 05:07:52',
#   'Lat': 12.71,
#   'Lng': 104.89,
#   'Max Temp': 96.08,
#   'Humidity': 19,
#   'Cloudiness': 8,
#   'Wind Speed': 8.99,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Moshenskoye',
#   'Country': 'RU',
#   'Date': '2020-02-24 05:07:52',
#   'Lat': 58.51,
#   'Lng': 34.59,
#   'Max Temp': 32.32,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 10.27,
#   'Current Description': 'light snow',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0.69},
#  {'City': 'Vitimskiy',
#   'Country': 'RU',
#   'Date': '2020-02-24 05:07:52',
#   'Lat': 58.51,
#   'Lng': 34.59,
#   'Max Temp': 32.32,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 10.27,
#   'Current Description': 'light snow',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Caravelas',
#   'Country': 'BR',
#   'Date': '2020-02-24 05:07:53',
#   'Lat': -17.71,
#   'Lng': -39.25,
#   'Max Temp': 79.77,
#   'Humidity': 83,
#   'Cloudiness': 34,
#   'Wind Speed': 9.51,
#   'Current Description': 'moderate rain',
#   'Rain inches (last 3 hrs)': 3.25,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Kristiinankaupunki',
#   'Country': 'FI',
#   'Date': '2020-02-24 05:07:53',
#   'Lat': 62.27,
#   'Lng': 21.38,
#   'Max Temp': 31.66,
#   'Humidity': 55,
#   'Cloudiness': 21,
#   'Wind Speed': 15.21,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Vigia Del Fuerte',
#   'Country': 'CO',
#   'Date': '2020-02-24 05:07:53',
#   'Lat': 6.58,
#   'Lng': -76.89,
#   'Max Temp': 72.81,
#   'Humidity': 89,
#   'Cloudiness': 17,
#   'Wind Speed': 3.65,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Tortoli',
#   'Country': 'IT',
#   'Date': '2020-02-24 05:07:53',
#   'Lat': 39.93,
#   'Lng': 9.66,
#   'Max Temp': 51.8,
#   'Humidity': 62,
#   'Cloudiness': 5,
#   'Wind Speed': 4.7,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Khash',
#   'Country': 'IR',
#   'Date': '2020-02-24 05:07:53',
#   'Lat': 28.22,
#   'Lng': 61.22,
#   'Max Temp': 63.41,
#   'Humidity': 38,
#   'Cloudiness': 0,
#   'Wind Speed': 5.19,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Hofn',
#   'Country': 'IS',
#   'Date': '2020-02-24 05:03:04',
#   'Lat': 64.25,
#   'Lng': -15.21,
#   'Max Temp': 38.98,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 28.99,
#   'Current Description': 'light snow',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0.63},
#  {'City': 'Cavalcante',
#   'Country': 'BR',
#   'Date': '2020-02-24 05:07:54',
#   'Lat': -13.8,
#   'Lng': -47.46,
#   'Max Temp': 65.8,
#   'Humidity': 88,
#   'Cloudiness': 86,
#   'Wind Speed': 0.51,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Shingu',
#   'Country': 'JP',
#   'Date': '2020-02-24 05:07:54',
#   'Lat': 33.73,
#   'Lng': 135.98,
#   'Max Temp': 57.2,
#   'Humidity': 50,
#   'Cloudiness': 0,
#   'Wind Speed': 11.41,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Mahibadhoo',
#   'Country': 'MV',
#   'Date': '2020-02-24 05:07:54',
#   'Lat': 3.78,
#   'Lng': 72.97,
#   'Max Temp': 83.03,
#   'Humidity': 76,
#   'Cloudiness': 39,
#   'Wind Speed': 15.61,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Perth',
#   'Country': 'AU',
#   'Date': '2020-02-24 05:07:25',
#   'Lat': -31.93,
#   'Lng': 115.83,
#   'Max Temp': 90,
#   'Humidity': 45,
#   'Cloudiness': 40,
#   'Wind Speed': 13.87,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0},
#  {'City': 'Whyalla',
#   'Country': 'AU',
#   'Date': '2020-02-24 05:07:55',
#   'Lat': -33.03,
#   'Lng': 137.58,
#   'Max Temp': 87.8,
#   'Humidity': 43,
#   'Cloudiness': 0,
#   'Wind Speed': 11.41,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3 hrs)': 0,
#   'Snow inches (last 3 hrs)': 0}]

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#             City Country                 Date    Lat     Lng  Max Temp  \
# 0    Surat Thani      TH  2020-02-24 05:05:33   9.14   99.33    106.00
# 1     Butaritari      KI  2020-02-24 05:05:33   3.07  172.79     82.06
# 2         Lompoc      US  2020-02-24 05:05:33  34.64 -120.46     55.40
# 3          Jumla      NP  2020-02-24 05:05:33  29.27   82.18     49.05
# 4          Tiksi      RU  2020-02-24 05:05:34  71.69  128.87     -3.64
# ..           ...     ...                  ...    ...     ...       ...
# 621   Cavalcante      BR  2020-02-24 05:07:54 -13.80  -47.46     65.80
# 622       Shingu      JP  2020-02-24 05:07:54  33.73  135.98     57.20
# 623   Mahibadhoo      MV  2020-02-24 05:07:54   3.78   72.97     83.03
# 624        Perth      AU  2020-02-24 05:07:25 -31.93  115.83     90.00
# 625      Whyalla      AU  2020-02-24 05:07:55 -33.03  137.58     87.80
#
#      Humidity  Cloudiness  Wind Speed Current Description  \
# 0          58          20       10.29          few clouds
# 1          84          68       26.22       moderate rain
# 2          87          90        3.36     overcast clouds
# 3          29          24        4.32          few clouds
# 4          87          98        7.31     overcast clouds
# ..        ...         ...         ...                 ...
# 621        88          86        0.51     overcast clouds
# 622        50           0       11.41           clear sky
# 623        76          39       15.61    scattered clouds
# 624        45          40       13.87    scattered clouds
# 625        43           0       11.41           clear sky
#
#      Rain inches (last 3 hrs)  Snow inches (last 3 hrs)
# 0                        0.00                       0.0
# 1                        9.44                       0.0
# 2                        0.00                       0.0
# 3                        0.00                       0.0
# 4                        0.00                       0.0
# ..                        ...                       ...
# 621                      0.00                       0.0
# 622                      0.00                       0.0
# 623                      0.00                       0.0
# 624                      0.00                       0.0
# 625                      0.00                       0.0
#
# [626 rows x 12 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_challenge.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City")

# %%
desc_group=city_data_df.groupby(['Current Description']).count()
desc_group
# Out:
#                              City  Country  Date  Lat  Lng  Max Temp  \
# Current Description
# broken clouds                  85       85    85   85   85        85
# clear sky                     129      129   129  129  129       129
# dust                            3        3     3    3    3         3
# few clouds                     79       79    79   79   79        79
# fog                             3        3     3    3    3         3
# haze                            4        4     4    4    4         4
# light intensity drizzle         2        2     2    2    2         2
# light intensity shower rain     1        1     1    1    1         1
# light rain                     49       49    49   49   49        49
# light shower snow               4        4     4    4    4         4
# light snow                     41       41    41   41   41        41
# mist                            3        3     3    3    3         3
# moderate rain                  11       11    11   11   11        11
# overcast clouds               128      128   128  128  128       128
# scattered clouds               76       76    76   76   76        76
# shower rain                     4        4     4    4    4         4
# snow                            4        4     4    4    4         4
#
#                              Humidity  Cloudiness  Wind Speed  \
# Current Description
# broken clouds                      85          85          85
# clear sky                         129         129         129
# dust                                3           3           3
# few clouds                         79          79          79
# fog                                 3           3           3
# haze                                4           4           4
# light intensity drizzle             2           2           2
# light intensity shower rain         1           1           1
# light rain                         49          49          49
# light shower snow                   4           4           4
# light snow                         41          41          41
# mist                                3           3           3
# moderate rain                      11          11          11
# overcast clouds                   128         128         128
# scattered clouds                   76          76          76
# shower rain                         4           4           4
# snow                                4           4           4
#
#                              Rain inches (last 3 hrs)  \
# Current Description
# broken clouds                                      85
# clear sky                                         129
# dust                                                3
# few clouds                                         79
# fog                                                 3
# haze                                                4
# light intensity drizzle                             2
# light intensity shower rain                         1
# light rain                                         49
# light shower snow                                   4
# light snow                                         41
# mist                                                3
# moderate rain                                      11
# overcast clouds                                   128
# scattered clouds                                   76
# shower rain                                         4
# snow                                                4
#
#                              Snow inches (last 3 hrs)
# Current Description
# broken clouds                                      85
# clear sky                                         129
# dust                                                3
# few clouds                                         79
# fog                                                 3
# haze                                                4
# light intensity drizzle                             2
# light intensity shower rain                         1
# light rain                                         49
# light shower snow                                   4
# light snow                                         41
# mist                                                3
# moderate rain                                      11
# overcast clouds                                   128
# scattered clouds                                   76
# shower rain                                         4
# snow                                                4
